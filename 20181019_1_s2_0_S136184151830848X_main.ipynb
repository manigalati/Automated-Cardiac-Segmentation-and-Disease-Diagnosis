# %%
# !rm -r sample_data

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-503ad953-e25b-9f12-3f45-f59f3f9055f0)

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print('Tensorflow version: {}'.format(tf.__version__))
# Out:
# TensorFlow 1.x selected.
# Tensorflow version: 1.15.2

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install requirements

# %%
# !pip install SimpleITK
# Out:
# ...
#      |████████████████████████████████| 42.5MB 73kB/s
# ...

# %% [markdown]
# ## Import data

# %%
# !git clone https://github.com/manigalati/Automated-Cardiac-Segmentation-and-Disease-Diagnosis
# Out:
# Cloning into 'Automated-Cardiac-Segmentation-and-Disease-Diagnosis'...
# remote: Enumerating objects: 167, done.
# remote: Total 167 (delta 0), reused 0 (delta 0), pack-reused 167
# Receiving objects: 100% (167/167), 7.37 MiB | 8.80 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %% [markdown]
# ## Prepare dataset

# %%
# %cd /content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis
# Out:
# /content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis

# %%
# !mkdir -p /content/ACDC_DataSet
# !unzip -q "/content/drive/My Drive/tesi/training.zip" -d /content/ACDC_DataSet
# !unzip -q "/content/drive/My Drive/tesi/testing.zip" -d /content/ACDC_DataSet

# %%
# !mv /content/ACDC_DataSet/testing/testing /content/ACDC_DataSet/tmp && rm -r /content/ACDC_DataSet/testing && mv /content/ACDC_DataSet/tmp /content/ACDC_DataSet/testing

# %%
import os
os.environ['PYTHONPATH'] += ":/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis"
os.environ['PYTHONPATH'] += ":/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/helpers"
os.environ['PYTHONPATH'] += ":/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/data_loaders"
os.environ['PYTHONPATH'] += ":/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/data_preprocess"
os.environ['PYTHONPATH'] += ":/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/models"
# !echo $PYTHONPATH
# Out:
# /tensorflow-1.15.2/python3.6:/env/python:/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis:/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/helpers:/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/data_loaders:/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/data_preprocess:/content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/models

# %%
# %cd /content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/data_preprocess
# Out:
# /content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/data_preprocess

# %%
# !python acdc_data_preparation.py
# Out:
# ---Time taken to stratify the dataset 46.124722719192505 seconds ---
# ROI->ED->ES train dataset
# ../../processed_acdc_dataset/dataset/train_set
#   0% 0/70 [00:00<?, ?it/s]../../processed_acdc_dataset/dataset/train_set/patient001/Info.cfg
#   1% 1/70 [00:03<04:02,  3.51s/it]../../processed_acdc_dataset/dataset/train_set/patient002/Info.cfg
#   3% 2/70 [00:04<03:08,  2.78s/it]../../processed_acdc_dataset/dataset/train_set/patient003/Info.cfg
#   4% 3/70 [00:05<02:32,  2.27s/it]../../processed_acdc_dataset/dataset/train_set/patient007/Info.cfg
#   6% 4/70 [00:06<01:58,  1.80s/it]../../processed_acdc_dataset/dataset/train_set/patient009/Info.cfg
#   7% 5/70 [00:07<01:45,  1.62s/it]../../processed_acdc_dataset/dataset/train_set/patient010/Info.cfg
#   9% 6/70 [00:08<01:32,  1.44s/it]../../processed_acdc_dataset/dataset/train_set/patient011/Info.cfg
#  10% 7/70 [00:09<01:17,  1.24s/it]../../processed_acdc_dataset/dataset/train_set/patient012/Info.cfg
# ...

# %% [markdown]
# ## Training

# %%
# %cd /content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/estimators
# Out:
# /content/Automated-Cardiac-Segmentation-and-Disease-Diagnosis/estimators

# %%
# !python train.py
# Out:
# WARNING:tensorflow:From ../models/network_ops.py:4: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:15: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Defining the network FCRD_ACDC
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ../models/network.py:74: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# ...

# %% [markdown]
# ## Testing

# %%
# !cp -r "/content/drive/My Drive/tesi/20181019_1-s2.0-S136184151830848X-main_RESULTS/trained_models" /content/trained_models

# %%
# !python test.py
# Out:
# WARNING:tensorflow:From ../models/network_ops.py:4: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From test.py:49: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Defining the network FCRD_ACDC
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From ../models/network.py:74: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# ...

# %%
# !gzip -k /content/trained_models/ACDC/FCRD_ACDC/predictions20200914_144014/models/testing/patient101/patient101_ED.nii

# %%
import os
test_dir="/content/trained_models/ACDC/FCRD_ACDC/predictions20200914_144014/models/testing/"
for dir in os.listdir(test_dir):
  if os.path.isdir(test_dir+dir):

    source=test_dir+dir+"/"+dir+"_ED.nii"
    # !gzip -k $source -f
    source=test_dir+dir+"/"+dir+"_ED.nii.gz"
    dst='"/content/drive/My Drive/tesi/20181019_1-s2.0-S136184151830848X-main_RESULTS/results/"'
    # !cp $source $dst

    source=test_dir+dir+"/"+dir+"_ES.nii"
    # !gzip -k $source -f
    source=test_dir+dir+"/"+dir+"_ES.nii.gz"
    dst='"/content/drive/My Drive/tesi/20181019_1-s2.0-S136184151830848X-main_RESULTS/results/"'
    # !cp $source $dst
